# %%
import os # to create an interface with our operating system
import sys # information on how our code is interacting with the host system
import pymongo # for working with the MongoDB API

# %%
client = pymongo.MongoClient('mongodb://localhost:27017')

# %%
 db = client.Music5

# %%
collection = db.Music_song

# %%
test = collection.find_one()

# %%
import pandas as pd

# %%
data = pd.DataFrame(list(db.Music_song.find()))

# %%
data
# Out:
#                          _id  id                 Audio                Artist  \
# 0   61aff007b9026a519d9cbcfa   7            In Da Club               50 Cent
# 1   61aff034b9026a519d9cbcfc   8                    Up               Cardi B
# 2   61aff077b9026a519d9cbcfe   9                   Wap               Cardi B
# 3   61aff0b7b9026a519d9cbd00  10    Every chance I Get             Dj Khaled
# 4   61aff0f7b9026a519d9cbd02  11                 Ridin        Chamillionaire
# 5   61aff132b9026a519d9cbd04  12               Rapstar                Polo G
# 6   61b12c986753e8dc3fae06b1  13       Better Together            Luke Combs
# 7   61b12ccc6753e8dc3fae06b3  14              Bon Jovi  Wanted dead or alive
# 8   61b12d2c6753e8dc3fae06b5  15          Foo Fighters              Everlong
# 9   61b12d686753e8dc3fae06b7  16     She will be loved              Maroon 5
# 10  61b12db26753e8dc3fae06b9  17    She talk to angels      The Black Crowes
# 11  61b205b2a08d7c4231481ddf  18           Galway Girl            Ed Sheeran
# 12  61b205f6a08d7c4231481de1  19               Perfect            Ed Sheeren
# 13  61b20626a08d7c4231481de3  20                 Happy      Pharrel Williams
# 14  61b20671a08d7c4231481de5  21     Party Rock Anthem                 LMFAO
# 15  61b20698a08d7c4231481de7  22                  Yeah                 Usher
# 16  61b2070ca08d7c4231481de9  23     Thinking Out Loud            Ed Sheeren
# 17  61b2074ba08d7c4231481deb  24         We Found Love               Rihanna
# 18  61b2a01f3a48ab500d5c22d1  25            Phone Dies             Andra Day
# 19  61b2a06f3a48ab500d5c22d3  26            Old Brazil       Beverley Beirne
# 20  61b2a1d43a48ab500d5c22d5  27          Look of love          Dianna Krall
# 21  61b2a20d3a48ab500d5c22d7  28         Blue in green           Miles Davis
# 22  61b4b43e52fcadb91c5a27b6  29                 Grave           Dee Yan-Key
# 23  61b4b48552fcadb91c5a27b8  30  Non troppo sostenuto           Dee Yan-Key
# 24  61b4b4ab52fcadb91c5a27ba  31         World of Snow           Dee Yan-Key
# 25  61b4b4e452fcadb91c5a27bc  32              Farewell   Maarten Schellekens
#
#                                             Audiofile  \
# 0                           50_Cent_-__In_Da_Club.mp3
# 1                                    Cardi_B_-_Up.mp3
# 2     nicki-minaj-stallion-wap-Thinknews.com_.ng_.mp3
# 3                                 everychanceiget.mp3
# 4         Chamillionaire_-_Ridin_ft._Krayzie_Bone.mp3
# 5                   Polo-G-RAPSTAR-Official-Video.mp3
# 6                    Luke_Combs_-_Better_Together.mp3
# 7       Bon_Jovi_-_Wanted_Dead_Or_Alive_Qoret.com.mp3
# 8                                        everlong.mp3
# 9                               She_Will_Be_Loved.mp3
# 10                               SheTalksToAngels.mp3
# 11                                     galwaygirl.jpg
# 12          Ed_Sheeran_-_Perfect_thinknews.com.ng.mp3
# 13    Pharrell-Williams-Happy-Mybestfeelings.com_.mp3
# 14  LMFAO_ft_Lauren_Bennett_GoonRock_-_Party_Rock_...
# 15             Usher_-_Yeah_ft._Ludacris__Lil_Jon.mp3
# 16  Ed_Sheeran_-_Thinking_Out_Loud-AFROBEAT.co.za.mp3
# 17      Rihanna_-_We_Found_Love_ft._Calvin_Harris.mp3
# 18  Andra_Day_-_Phone_Dies_prod._Anderson_.Paak_32...
# 19                             To_Brazil_320_Kbps.mp3
# 20                   diana-krall-the-look-of-love.mp3
# 21                                    BlueInGreen.mp3
# 22                            Dee_Yan-Key_-_Grave.mp3
# 23             Dee_Yan-Key_-_Non_troppo_sostenuto.mp3
# 24                    Dee_Yan-Key_-_World_of_Snow.mp3
# 25           Maarten_Schellekens_-_Farewell_Remix.mp3
#
#                                              Imageurl      Genre  Time   color
# 0                                        indaclub.jpg     HipHop  4.00    blue
# 1                                              up.jpg     HipHop  4.00   green
# 2                                             wap.jpg     HipHop  4.00   white
# 3                                    oneverything.jpg     HipHop  4.00  yellow
# 4                                           ridin.jpg     HipHop  4.00    grey
# 5                                         rapstar.jpg     HipHop  4.00  bisque
# 6                                  bettertogether.jpg   Acoustic  4.00   green
# 7                               wanteddeadoralive.jpg   Acoustic  4.00    blue
# 8                                        everlong.jpg   Acoustic  4.00     red
# 9                                  shewillbeloved.jpg   Acoustic  4.00    grey
# 10                            She_Talks_to_Angels.jpg   Acoustic  4.00  yellow
# 11                             galwaygirl_9aN1gsH.jpg      Dance  4.00  bisque
# 12                                        perfect.jpg      Dance  4.00   white
# 13                                         happy.jpeg      Dance  4.00    blue
# 14  LMFAO-ft.-Lauren-Bennett-GoonRock-Party-Rock-A...      Dance  4.00   green
# 15                                           yeah.jpg      Dance  4.00    grey
# 16                                thinkingoutloud.jpg      Dance  4.00  orange
# 17                                    wefoundlove.jpg      Dance  4.00   beige
# 18                                      phonedies.jpg       Jazz  4.00    grey
# 19                                      oldbrazil.jpg       Jazz  4.00     red
# 20                                     lookoflove.jpg       Jazz  4.00   green
# 21                                    blueingreen.jpg       Jazz  4.00  orange
# 22                       guitar-siren-nikki-smith.jpg  Classical  4.00   green
# 23  pngtree-simple-classical-chinese-style-wind-an...  Classical  4.00     red
# 24  pngtree-simple-classical-chinese-style-wind-an...  Classical  4.00  orange
# 25  pngtree-simple-classical-chinese-style-wind-an...  Classical  4.00   white

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\harman\appdata\local\programs\python\python39\lib\site-packages (5.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\harman\appdata\local\programs\python\python39\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\harman\appdata\roaming\python\python39\site-packages (from plotly) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\harman\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
 import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataframe = data

# %%
dataframe.groupby('Artist')['id'].nunique().plot(kind='bar')
plt.show()

# %%
 dataframe.groupby('Genre')['id'].nunique().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Genre'>
